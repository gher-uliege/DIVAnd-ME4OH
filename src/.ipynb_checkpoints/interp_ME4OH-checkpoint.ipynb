# %%
using NCDatasets
using DIVAnd
using PyPlot
using Dates
using Glob
using Test
const plt = PyPlot
include("../config.jl");
include("../ME4OH.jl")
doplot = false
# Out:
# false

# %%
datafilelist = Glob.glob("*.nc", datadir)
@info("Found $(length(datafilelist)) files");
# Out:
# [ Info: Found 282 files
# "/home/ctroupin/data/ME4OH/data/en4.1.1/1979-2014/full/update/ofam3-jra55.all.EN.4.1.1.f.profiles.g10.197901.update.nc"

# %% [markdown]
# ## Create land-sea mask

# %%
lon, lat, dates, depth, T, S, dohc = read_profile(datafilelist[1])
xi, yi, mask = DIVAnd.load_mask(bathyfile, true, longrid, latgrid, depth);

# %% [markdown]
# ### Create metrics

# %%
_, pmn, xyi = DIVAnd_rectdom(longrid, latgrid, depth);

# %%
npoints = 0
lonall = Float32[]
for datafile in datafilelist
    lon, lat, dates, depth, T, S = read_profile(datafile)
    npoints += length(lon)
end

# %% [markdown]
# ## Experiment A
# We perform purely 2D interpolations by looping on the monthly periods and the depth levels.

# %%
depth_dohc = [depthlayer1[end], depthlayer2[end], depthlayer3[end]]
# Out:
# 3-element Vector{Float64}:
#   286.6
#   685.9
#  1985.3

# %%
xi, yi, mask_dohc = DIVAnd.load_mask(bathyfile, true, longrid, latgrid, depth_dohc);        
_, (pm, pn), (xi, yi) = DIVAnd_rectdom(longrid, latgrid);

# %%
fname = make_fname(timeperiod1, depthlayer1, "A")

for datafile in datafilelist[1:1]
    
    # Read observations
    lon, lat, dates, depth, T, S, dohc = read_profile(datafile)
    
    # Modify coordinates
    lon[lon .< 20.] .+= 360
    
    # Loop on the 3 depth levels
    for ii = 1:1
        
        # Select good values (no NaNs)
        obsval = dohc[ii,:]
        goodval = findall(.!isnan.(obsval));
        
        # Perform interpolation
        fi, s = DIVAndrun(mask_dohc[:,:,ii], (pm, pn), (xi, yi), (Float64.(lon[goodval]), 
        Float64.(lat[goodval])), Float64.(obsval[goodval] .- mean(obsval[goodval])), 
        (5., 5.), 10.; moddim=[1,0])
        
        # Write in a netCDF
        
        
        # Make plot
        if doplot
            fig = plt.figure(figsize=(15, 8))
            ax = plt.subplot(121)
            ax.scatter(lon[goodval], lat[goodval], s=3, c=obsval[goodval])
            ax.set_xlim(20., 380.)
            ax = plt.subplot(122)
            ax.pcolormesh(longrid, latgrid, fi' .+ mean(obsval[goodval]))
            ax.set_xlim(20., 380.)
            plt.show()
        end
    end
end
# Out:
# Figure(PyObject <Figure size 1500x800 with 2 Axes>)

# %%
fname = make_fname(timeperiod1, depthlayer1, "A")
# Out:
# "OHC_1979_2014_lev0_286.6_expA_DIVAnd.nc"
